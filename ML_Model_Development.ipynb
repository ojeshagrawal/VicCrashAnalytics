# %%
#Predictors for our ML model
features = ['ROAD_TYPE', 'AGE_LESS_THAN_15YRS_PCNT', 'AGE_15_24YRS_PCNT', 'AGE_25_44YRS_PCNT', 'AGE_45_64YRS_PCNT', 'AGE_65YRS_OVER_PCNT', 'FC_COUPLE_NO_CHILDREN_PCNT', 'Intersection','traffic_signal','km_post','secondary_school','primary_school','Supermarket','Primary_Production%','Parkland%','Residential%','Industrial%','Commercial%','DWELLING_FLAT_UNIT_APART_PCNT','DWELLING_SEMID_RO_OR_TCE_H_TH_P','DWELLING_SEP_HOUSE_PCNT','FC_COUPLE_WITH_CHILDREN_PCNT', 'CARS_ONE_HH_PCNT', 'CARS_TWO_OR_MORE_HH_PCNT' ]

X = X=records[features]

#and our label attribute
y=records['BLACKSPOTS']

# %%
# checking how many rows and columns are there
X.shape
# Out:
# (5326, 24)

# %%
y.shape
# Out:
# (5326,)

# %% [markdown]
# <a id = "cell_modeling"></a>
# ## 3. Machine learning model development
#
#
# This section includes:
# * How to split dataset.
# * How to initiate machine learning model and fit training data.
# * How to use trained model to predict labels for training and testing dataset.

# %%
# Code
from sklearn.model_selection import train_test_split

# %%
# now we are splitting out dataset for testing and training, we are using 80% for testing and 20% for training
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
#looking whether the splitted dataset are right or not
print(X_train.info())
print(X_test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4260 entries, 593 to 5157
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ROAD_TYPE                        4260 non-null   int64
#  1   AGE_LESS_THAN_15YRS_PCNT         4260 non-null   float64
#  2   AGE_15_24YRS_PCNT                4260 non-null   float64
#  3   AGE_25_44YRS_PCNT                4260 non-null   float64
#  4   AGE_45_64YRS_PCNT                4260 non-null   float64
#  5   AGE_65YRS_OVER_PCNT              4260 non-null   float64
#  6   FC_COUPLE_NO_CHILDREN_PCNT       4260 non-null   float64
#  7   Intersection                     4260 non-null   int64
#  8   traffic_signal                   4260 non-null   int64
#  9   km_post                          4260 non-null   int64
#  10  secondary_school                 4260 non-null   int64
#  11  primary_school                   4260 non-null   int64
#  12  Supermarket                      4260 non-null   int64
#  13  Primary_Production%              4260 non-null   float64
#  14  Parkland%                        4260 non-null   float64
#  15  Residential%                     4260 non-null   float64
#  16  Industrial%                      4260 non-null   float64
#  17  Commercial%                      4260 non-null   float64
#  18  DWELLING_FLAT_UNIT_APART_PCNT    4260 non-null   float64
#  19  DWELLING_SEMID_RO_OR_TCE_H_TH_P  4260 non-null   float64
#  20  DWELLING_SEP_HOUSE_PCNT          4260 non-null   float64
#  21  FC_COUPLE_WITH_CHILDREN_PCNT     4260 non-null   float64
#  22  CARS_ONE_HH_PCNT                 4260 non-null   float64
#  23  CARS_TWO_OR_MORE_HH_PCNT         4260 non-null   float64
# dtypes: float64(17), int64(7)
# memory usage: 832.0 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1066 entries, 4817 to 2027
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ROAD_TYPE                        1066 non-null   int64
#  1   AGE_LESS_THAN_15YRS_PCNT         1066 non-null   float64
#  2   AGE_15_24YRS_PCNT                1066 non-null   float64
#  3   AGE_25_44YRS_PCNT                1066 non-null   float64
#  4   AGE_45_64YRS_PCNT                1066 non-null   float64
#  5   AGE_65YRS_OVER_PCNT              1066 non-null   float64
#  6   FC_COUPLE_NO_CHILDREN_PCNT       1066 non-null   float64
#  7   Intersection                     1066 non-null   int64
#  8   traffic_signal                   1066 non-null   int64
#  9   km_post                          1066 non-null   int64
#  10  secondary_school                 1066 non-null   int64
#  11  primary_school                   1066 non-null   int64
#  12  Supermarket                      1066 non-null   int64
#  13  Primary_Production%              1066 non-null   float64
#  14  Parkland%                        1066 non-null   float64
#  15  Residential%                     1066 non-null   float64
#  16  Industrial%                      1066 non-null   float64
#  17  Commercial%                      1066 non-null   float64
#  18  DWELLING_FLAT_UNIT_APART_PCNT    1066 non-null   float64
#  19  DWELLING_SEMID_RO_OR_TCE_H_TH_P  1066 non-null   float64
#  20  DWELLING_SEP_HOUSE_PCNT          1066 non-null   float64
#  21  FC_COUPLE_WITH_CHILDREN_PCNT     1066 non-null   float64
#  22  CARS_ONE_HH_PCNT                 1066 non-null   float64
#  23  CARS_TWO_OR_MORE_HH_PCNT         1066 non-null   float64
# dtypes: float64(17), int64(7)
# memory usage: 208.2 KB
# None

# %%
#creation of logistic regression model as it is the problem of classification
logreg = LogisticRegression(max_iter=100)
logreg
# Out:
# LogisticRegression()

# %%
#training the model
logreg = logreg.fit(X_train, y_train)

# %%
#making predictions using the model
y_pred = logreg.predict(X_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
#looking wheter the predicted values are similar to or not the actual values
y_test.values.T
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
#here we are creating a table of camparision whether the prdeicted and actul values corelate or not
inspection=pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})

inspection=pd.concat([X_test,inspection], axis=1)
#looking at initial 15 entries
inspection.head(15)
# Out:
#       ROAD_TYPE  AGE_LESS_THAN_15YRS_PCNT  AGE_15_24YRS_PCNT  \
# 4817          0                  0.271825           0.083333
# 1039          3                  0.163090           0.124464
# 4700          3                  0.141921           0.124454
# 3194          3                  0.185304           0.102236
# 440           4                  0.218519           0.133333
# 1034          3                  0.144847           0.130919
# 4166          3                  0.206522           0.101449
# 3546          3                  0.126521           0.102190
# 4365          4                  0.121988           0.058735
# 1774          3                  0.218054           0.080891
# 2847          3                  0.204509           0.098229
# 4926          2                  0.268759           0.070941
# 5160          4                  0.087264           0.070755
# 988           4                  0.203175           0.112698
# 2488          3                  0.121495           0.130841
#
#       AGE_25_44YRS_PCNT  AGE_45_64YRS_PCNT  AGE_65YRS_OVER_PCNT  \
# 4817           0.236111           0.271825             0.136905
# 1039           0.180258           0.360515             0.171674
# 4700           0.148472           0.351528             0.233624
# 3194           0.194888           0.348243             0.169329
# 440            0.224074           0.259259             0.164815
# 1034           0.208914           0.348189             0.167131
# 4166           0.188406           0.344203             0.159420
# 3546           0.182482           0.350365             0.238443
# 4365           0.228916           0.269578             0.320783
# 1774           0.256741           0.237984             0.206331
# 2847           0.198068           0.336554             0.162641
# 4926           0.312415           0.263302             0.084584
# 5160           0.117925           0.271226             0.452830
# 988            0.196825           0.307937             0.179365
# 2488           0.233645           0.392523             0.121495
#
#       FC_COUPLE_NO_CHILDREN_PCNT  Intersection  traffic_signal  km_post  ...  \
# 4817                    0.391304             1               0        0  ...
# 1039                    0.428571             1               0        0  ...
# 4700                    0.488189             1               0        0  ...
# 3194                    0.505155             1               0        1  ...
# 440                     0.321429             0               0        0  ...
# 1034                    0.456522             1               0        0  ...
# 4166                    0.387283             1               0        0  ...
# 3546                    0.500000             1               0        0  ...
# 4365                    0.575758             0               0        1  ...
# 1774                    0.466667             1               0        0  ...
# 2847                    0.441860             1               0        0  ...
# 4926                    0.380488             1               0        1  ...
# 5160                    0.589474             0               0        1  ...
# 988                     0.416667             1               0        0  ...
# 2488                    0.285714             1               0        0  ...
#
#       Industrial%  Commercial%  DWELLING_FLAT_UNIT_APART_PCNT  \
# 4817          0.0     0.000000                       0.000000
# 1039          0.0     0.000000                       0.000000
# 4700          0.0     0.000000                       0.000000
# 3194          0.0     0.000000                       0.000000
# 440           0.0     0.000000                       0.014778
# 1034          0.0     0.000000                       0.000000
# 4166          0.0     0.000000                       0.000000
# 3546          0.0     0.000000                       0.000000
# 4365          0.0     0.177746                       0.122727
# 1774          0.0     0.000000                       0.000000
# 2847          0.0     0.000000                       0.000000
# 4926          0.0     0.000000                       0.000000
# 5160          0.0     0.000000                       0.000000
# 988           0.0     0.000000                       0.000000
# 2488          0.0     0.000000                       0.000000
#
#       DWELLING_SEMID_RO_OR_TCE_H_TH_P  DWELLING_SEP_HOUSE_PCNT  \
# 4817                         0.000000                 1.000000
# 1039                         0.000000                 1.000000
# 4700                         0.025157                 0.955975
# 3194                         0.000000                 1.000000
# 440                          0.039409                 0.945813
# 1034                         0.000000                 1.000000
# 4166                         0.000000                 0.984375
# 3546                         0.000000                 1.000000
# 4365                         0.059091                 0.745455
# 1774                         0.025157                 0.959119
# 2847                         0.000000                 1.000000
# 4926                         0.000000                 1.000000
# 5160                         0.000000                 1.000000
# 988                          0.025316                 0.928270
# 2488                         0.000000                 1.000000
#
#       FC_COUPLE_WITH_CHILDREN_PCNT  CARS_ONE_HH_PCNT  \
# 4817                      0.485507          0.322981
# 1039                      0.571429          0.162162
# 4700                      0.377953          0.248408
# 3194                      0.360825          0.177570
# 440                       0.464286          0.405128
# 1034                      0.423913          0.121739
# 4166                      0.514451          0.128866
# 3546                      0.325000          0.278481
# 4365                      0.303030          0.429224
# 1774                      0.333333          0.387500
# 2847                      0.406977          0.188841
# 4926                      0.590244          0.133603
# 5160                      0.252632          0.547368
# 988                       0.403846          0.338912
# 2488                      0.785714          0.142857
#
#       CARS_TWO_OR_MORE_HH_PCNT  Actual  Predicted
# 4817                  0.652174       1          1
# 1039                  0.797297       1          1
# 4700                  0.732484       1          1
# 3194                  0.785047       1          1
# 440                   0.564103       1          1
# 1034                  0.852174       1          1
# 4166                  0.850515       1          1
# 3546                  0.683544       1          1
# 4365                  0.461187       1          0
# 1774                  0.537500       1          1
# 2847                  0.742489       1          1
# 4926                  0.834008       1          1
# 5160                  0.331579       0          1
# 988                   0.552301       1          1
# 2488                  0.857143       1          1
#
# [15 rows x 26 columns]

# %%
#looking at last entries (15)
inspection.tail(15)
# Out:
#       ROAD_TYPE  AGE_LESS_THAN_15YRS_PCNT  AGE_15_24YRS_PCNT  \
# 1081          3                  0.212308           0.104615
# 1852          3                  0.234450           0.124402
# 4716          0                  0.131532           0.079279
# 1587          0                  0.131532           0.079279
# 3301          4                  0.248780           0.126829
# 622           3                  0.144578           0.072289
# 1953          0                  0.166990           0.091262
# 3900          3                  0.185366           0.126829
# 2595          3                  0.248780           0.126829
# 804           0                  0.176378           0.140157
# 1030          3                  0.182573           0.062241
# 587           3                  0.211268           0.123239
# 3344          3                  0.163090           0.124464
# 4721          3                  0.201087           0.116848
# 2027          3                  0.177419           0.150538
#
#       AGE_25_44YRS_PCNT  AGE_45_64YRS_PCNT  AGE_65YRS_OVER_PCNT  \
# 1081           0.187692           0.378462             0.116923
# 1852           0.236045           0.261563             0.143541
# 4716           0.153153           0.291892             0.344144
# 1587           0.153153           0.291892             0.344144
# 3301           0.239024           0.273171             0.112195
# 622            0.162651           0.403614             0.216867
# 1953           0.217476           0.304854             0.219417
# 3900           0.187805           0.343902             0.156098
# 2595           0.239024           0.273171             0.112195
# 804            0.171654           0.277165             0.234646
# 1030           0.153527           0.398340             0.203320
# 587            0.207746           0.330986             0.126761
# 3344           0.180258           0.360515             0.171674
# 4721           0.198370           0.369565             0.114130
# 2027           0.153226           0.336022             0.182796
#
#       FC_COUPLE_NO_CHILDREN_PCNT  Intersection  traffic_signal  km_post  ...  \
# 1081                    0.494949             1               0        0  ...
# 1852                    0.333333             1               0        0  ...
# 4716                    0.521739             1               0        0  ...
# 1587                    0.521739             1               0        1  ...
# 3301                    0.289720             1               0        0  ...
# 622                     0.500000             1               0        0  ...
# 1953                    0.405797             1               0        0  ...
# 3900                    0.483333             1               0        0  ...
# 2595                    0.289720             1               0        0  ...
# 804                     0.352941             1               0        0  ...
# 1030                    0.458333             1               0        0  ...
# 587                     0.448276             1               0        0  ...
# 3344                    0.428571             1               0        0  ...
# 4721                    0.372549             1               0        0  ...
# 2027                    0.378641             1               0        0  ...
#
#       Industrial%  Commercial%  DWELLING_FLAT_UNIT_APART_PCNT  \
# 1081          0.0     0.000000                       0.000000
# 1852          0.0     0.000000                       0.000000
# 4716          0.0     0.010868                       0.098485
# 1587          0.0     0.198706                       0.098485
# 3301          0.0     0.000000                       0.000000
# 622           0.0     0.000000                       0.000000
# 1953          0.0     0.000000                       0.032258
# 3900          0.0     0.000000                       0.000000
# 2595          0.0     0.000000                       0.000000
# 804           0.0     0.000000                       0.000000
# 1030          0.0     0.000000                       0.000000
# 587           0.0     0.000000                       0.000000
# 3344          0.0     0.000000                       0.000000
# 4721          0.0     0.000000                       0.000000
# 2027          0.0     0.000000                       0.000000
#
#       DWELLING_SEMID_RO_OR_TCE_H_TH_P  DWELLING_SEP_HOUSE_PCNT  \
# 1081                         0.000000                 1.000000
# 1852                         0.000000                 1.000000
# 4716                         0.034091                 0.829545
# 1587                         0.034091                 0.829545
# 3301                         0.000000                 1.000000
# 622                          0.000000                 0.968992
# 1953                         0.000000                 0.967742
# 3900                         0.000000                 1.000000
# 2595                         0.000000                 1.000000
# 804                          0.012000                 0.976000
# 1030                         0.000000                 1.000000
# 587                          0.000000                 0.961165
# 3344                         0.000000                 1.000000
# 4721                         0.000000                 1.000000
# 2027                         0.000000                 1.000000
#
#       FC_COUPLE_WITH_CHILDREN_PCNT  CARS_ONE_HH_PCNT  \
# 1081                      0.494949          0.120690
# 1852                      0.488506          0.185366
# 4716                      0.246377          0.425455
# 1587                      0.246377          0.425455
# 3301                      0.570093          0.201493
# 622                       0.371795          0.214815
# 1953                      0.369565          0.412556
# 3900                      0.408333          0.195804
# 2595                      0.570093          0.201493
# 804                       0.405229          0.412955
# 1030                      0.333333          0.220000
# 587                       0.471264          0.125000
# 3344                      0.571429          0.162162
# 4721                      0.539216          0.160000
# 2027                      0.495146          0.139130
#
#       CARS_TWO_OR_MORE_HH_PCNT  Actual  Predicted
# 1081                  0.853448       1          1
# 1852                  0.765854       1          1
# 4716                  0.370909       1          1
# 1587                  0.370909       1          1
# 3301                  0.708955       1          1
# 622                   0.696296       1          1
# 1953                  0.479821       0          1
# 3900                  0.804196       1          1
# 2595                  0.708955       1          1
# 804                   0.425101       0          1
# 1030                  0.700000       1          1
# 587                   0.875000       1          1
# 3344                  0.797297       1          1
# 4721                  0.808000       1          1
# 2027                  0.826087       1          1
#
# [15 rows x 26 columns]
